# %% [markdown]
# # Module 0: Fleet
#
# > Part of the **Modular Workshops** series. Lightweight intro, ~10 min.
#
# Quick orientation to Fleet — what it is, how it fits with the rest of the LangChain stack. Walk through the deck, then jump into the Fleet UI to show it live.
#
# **Slides:** <https://docs.google.com/presentation/d/1o4A0zgPxXFyuznnGGikwu_xZMF-Pm1rnQTJQ3_BAMWc/edit?usp=sharing>

# %% [markdown]
# ## Open the Fleet UI
#
# Once the slides reach the demo section, open Fleet in a new tab and walk through it.
#
# **Fleet UI:** _TBD — paste the Fleet URL here._
